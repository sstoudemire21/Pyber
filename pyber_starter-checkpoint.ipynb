# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data = "Resources/city_data.csv"
ride_data = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data)
ride_data_df = pd.read_csv(ride_data)

# Combine the data into a single dataset
pyber_df = pd.merge(ride_data_df, city_data_df,
                                 how='left', on='city')
pyber_df.head()

# Display the data table for preview
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# # Bubble Plot of Ride Sharing Data

# %%
urban = pyber_df.loc[(pyber_df["type"] == "Urban")]
suburban = pyber_df.loc[(pyber_df["type"] == "Suburban")]
rural = pyber_df.loc[(pyber_df["type"] == "Rural")]

# %%
# Obtain the x and y coordinates for each of the three city types

#Per city calculations of Average Fare, Total Rides and Total Drivers
urban_avg_fare = urban.groupby(['city'])['fare'].mean()
urban_total_rides = urban.groupby(['city']).nunique()['ride_id']
urban_total_rides
urban_total_drivers = urban.groupby(['type'])['driver_count'].value_counts()

suburban_avg_fare = suburban.groupby(['city'])['fare'].mean()
suburban_total_rides = suburban.groupby(['city']).count()['ride_id']
suburban_total_rides
suburban_total_drivers = suburban.groupby(['city'])['driver_count'].value_counts()

rural_avg_fare = rural.groupby(['city'])['fare'].mean()
rural_total_rides = rural.groupby(['city']).nunique()['ride_id']
rural_total_rides
rural_total_drivers = rural.groupby(['city'])['driver_count'].value_counts()

# # Build the scatter plots for each city types
# #Gold, Light Sky Blue, and Light Coral
plt.scatter(urban_total_rides, urban_avg_fare, marker="o", facecolors="lightcoral", edgecolors="black",
             s=urban_total_drivers *10, alpha=0.5, linewidth=0.5, label="urban")

plt.scatter(suburban_total_rides, suburban_avg_fare, marker="o", facecolors="lightskyblue", edgecolors="black",
             s=suburban_total_drivers *10, alpha=0.5, linewidth=0.5, label="suburban")

plt.scatter(rural_total_rides, rural_avg_fare, marker="o", facecolors="gold", edgecolors="black",
             s=rural_total_drivers *10, alpha=0.5, linewidth=0.5, label="rural")

 
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.title("Ride Sharing")

# Create a legend
plt.legend(loc='upper right')
plt.text(0.3, 0.3, type, fontsize=14)

# Save Figure
plt.savefig("Resources/bubbleplt.png")

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
# total_types = pyber_df['fare'].sum()
# total_types

urban_total_fare = urban.groupby(['type']).sum()['fare'] / urban['fare'].sum()
urban_total_fare

suburban_total_fare = suburban.groupby(['type']).sum()['fare'] / suburban['fare'].sum()
suburban_total_fare

rural_total_fare = rural.groupby(['type']).sum()['fare'] / rural['fare'].sum()
rural_total_fare

# urban_percent = (urban_total_fare / total_types) * 100
# print(urban_percent)

# suburban_percent = (suburban_total_fare / total_types) * 100
# print(suburban_percent)

# rural_percent = (rural_total_fare / total_types) * 100
# print(rural_percent)

# Build Pie Chart
#Labels for the sections of our pie chart
labels = ["Urban", "Suburban", "Rural"]

# The values of each section of the pie chart
sizes = [62.7, 30.5, 6.8]

# The colors of each section of the pie chart
colors = ["gold", "lightskyblue", "lightcoral"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=150)

plt.title("% of Total Fares by City Type", bbox={'facecolor':'0.95', 'pad':0})

plt.axis("equal")

# # Save Figure
plt.savefig("Resources/totalfarepie.png")
# Out:
# (-1.1179159678026478,
#  1.1004111755053723,
#  -1.2182050276748169,
#  1.1188526531851681)

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
total_rides = pyber_df['ride_id'].sum()
total_rides


urban_total_rides = urban_reset.groupby(['type']).sum()['ride_id'] / total_rides
urban_total_rides

suburban_total_rides = suburban_reset.groupby(['type']).sum()['ride_id'] / total_rides
suburban_total_rides

rural_total_rides = rural_reset.groupby(['type']).sum()['ride_id'] / total_rides
rural_total_rides





# Build Pie Chart

# #Labels for the sections of our pie chart
labels = ["Urban", "Suburban", "Rural"]

# The values of each section of the pie chart
sizes = [68.4, 26.3, 5.3]

# The colors of each section of the pie chart
colors = ["lightskyblue", "lightcoral", "gold"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=150)

plt.title("% of Total Rides by City Type", bbox={'facecolor':'0.95', 'pad':0})

plt.axis("equal")


# Save Figure
plt.savefig("Resources/totalridespie.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

total_drivers = pyber_df['driver_count'].count()
total_drivers


urban_total_drivers = urban.groupby(['type'])['driver_count'].nunique()
urban_total_drivers

suburban_total_drivers = suburban.groupby(['type'])['driver_count'].nunique()
suburban_total_drivers

rural_total_drivers = rural.groupby(['type'])['driver_count'].nunique()
rural_total_drivers

# Build Pie Charts
# 45 18 7

#Labels for the sections of our pie chart
labels = ["Urban", "Suburban", "Rural"]

# The values of each section of the pie chart
sizes = [80.9, 16.5, 2.6]

# The colors of each section of the pie chart
colors = ["lightcoral", "gold", "lightskyblue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=150)

plt.title("% of Total Drivers by City Type", bbox={'facecolor':'0.95', 'pad':0})

plt.axis("equal")

# Save Figure
plt.savefig("Resources/totaldriverspie.png")

# %%
# Show Figure
plt.show()
